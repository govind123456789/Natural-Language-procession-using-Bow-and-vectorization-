# %%
from selenium import webdriver
import os

# %%
driver = webdriver.Chrome(executable_path ='chromedriver.exe')

# %%
def directory(dirname):
    current_path = os.getcwd()
    path = os.path.join(current_path, dirname)
    if not os.path.exists(path):
        os.makedirs(path)

# %%
directory("trouser")

# %%
import shutil
import requests

# %%
my_page =  driver.get("https://www.flipkart.com/search?q=trouser&sid=clo%2Cvua%2Cmle%2Clhk&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_7_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_7_na_na_na&as-pos=1&as-type=RECENT&suggestionId=trouser%7CMen%27s+Trousers&requestId=c3b8b801-c067-4890-b078-e0079be306c5&as-searchtext=trouser")
images1 = driver.find_elements_by_xpath("//img[@class='_2r_T1I']")
urls1=[]
for image in images1:
    source=image.get_attribute('src')
    urls1.append(source)
print(len(urls1))
my_page =  driver.get("https://www.flipkart.com/search?q=trouser&sid=clo%2Cvua%2Cmle%2Clhk&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_7_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_7_na_na_na&as-pos=1&as-type=RECENT&suggestionId=trouser%7CMen%27s+Trousers&requestId=c3b8b801-c067-4890-b078-e0079be306c5&as-searchtext=trouser&sort=recency_desc")
images0 = driver.find_elements_by_xpath("//img[@class='_2r_T1I']")
urls0=[]
for image in images0:
    source=image.get_attribute('src')
    urls0.append(source)
print(len(urls0))
my_page =  driver.get("https://www.flipkart.com/search?q=trouser&sid=clo%2Cvua%2Cmle%2Clhk&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_7_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_7_na_na_na&as-pos=1&as-type=RECENT&suggestionId=trouser%7CMen%27s+Trousers&requestId=c3b8b801-c067-4890-b078-e0079be306c5&as-searchtext=trouser&sort=popularity")
images2 = driver.find_elements_by_xpath("//img[@class='_2r_T1I']")
urls2=[]
for image in images2:
    source=image.get_attribute('src')
    urls2.append(source)
print(len(urls2))
my_page =  driver.get("https://www.amazon.com/s?k=trousers+for+men&ref=nb_sb_noss_2")
images3 = driver.find_elements_by_xpath("//img[@class='s-image']")
urls3=[]
for image in images3:
    source=image.get_attribute('src')
    urls3.append(source)
print(len(urls3))
my_page =  driver.get("https://www.amazon.com/s?k=trousers+for+men&s=date-desc-rank&qid=1609597096&ref=sr_st_date-desc-rank")
images = driver.find_elements_by_xpath("//img[@class='s-image']")
urls=[]
for image in images:
    source=image.get_attribute('src')
    urls.append(source)
print(len(urls))
# Out:
# 40
# 40
# 40
# 65
# 55

# %%
k=[urls,urls1,urls2,urls3,urls0]
url=[]
page=1
for i in k:
    for x in i:
        url.append(x)
len(url)
# Out:
# 240

# %%
for index, link in enumerate(i):
    print("Downloading {0} of{1} from page".format(index+1, len(urls)))
    response=requests.get(link)
    with open('trouser/img{0}.jpeg'.format(index,page),"wb")as file:
        file.write(response.content)
for index, link in enumerate(i):
    print("Downloading {0} of{1} from page".format(index+1, len(urls0)))
    response=requests.get(link)
    with open('trouser/imllg{0}.jpeg'.format(index,page),"wb")as file:
        file.write(response.content)
for index, link in enumerate(i):
    print("Downloading {0} of{1} from page".format(index+1, len(urls1)))
    response=requests.get(link)
    with open('trouser/pmg{0}.jpeg'.format(index,page),"wb")as file:
        file.write(response.content)
for index, link in enumerate(i):
    print("Downloading {0} of{1} from page".format(index+1, len(urls2)))
    response=requests.get(link)
    with open('trouser/pmkkg{0}.jpeg'.format(index,page),"wb")as file:
        file.write(response.content)
for index, link in enumerate(i):
    print("Downloading {0} of{1} from page".format(index+1, len(urls3)))
    response=requests.get(link)
    with open('trouser/pnnmg{0}.jpeg'.format(index,page),"wb")as file:
        file.write(response.content)
