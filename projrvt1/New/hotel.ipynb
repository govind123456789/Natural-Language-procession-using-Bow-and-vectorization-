# %% [markdown]
# # Introduction
# Currently customers are visiting your hotel and started dropping their reviews about your hotel and you have collected all the reviews up to data and you are clueless if those reviews represent positive or negative emotions (test).
#
# NLTK: the most famous python module for NLP techniques
# Gensim: a topic-modelling and vector space modelling toolkit
# Scikit-learn: the most used python machine learning library
#
# You would need to build a system to predict if the reviews are positive/negative, so that you can address any issues which are in the form of negative feedback.

# %%
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
from pprint import pprint
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.feature_extraction.text import CountVectorizer 
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import RFE
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, accuracy_score
#from sklearn.utils import s1804

# %% [markdown]
# # Load data
# We first start by loading the raw data. Each textual reviews is splitted into a positive part and a negative part. We group them together in order to start with only raw text data and no other information.

# %%
df = pd.read_csv('train.csv')

# %%
df2 = pd.read_csv('test.csv')

# %%
df.head()
# Out:
#    User_ID                                        Description  \
# 0  id10326  The room was kind of clean but had a VERY stro...
# 1  id10327  I stayed at the Crown Plaza April -- - April -...
# 2  id10328  I booked this hotel through Hotwire at the low...
# 3  id10329  Stayed here with husband and sons on the way t...
# 4  id10330  My girlfriends and I stayed here to celebrate ...
#
#         Browser_Used Device_Used Is_Response
# 0               Edge      Mobile   not happy
# 1  Internet Explorer      Mobile   not happy
# 2            Mozilla      Tablet   not happy
# 3   InternetExplorer     Desktop       happy
# 4               Edge      Tablet   not happy

# %%
df.isnull().sum()
# Out:
# User_ID         0
# Description     0
# Browser_Used    0
# Device_Used     0
# Is_Response     0
# dtype: int64

# %%
df1=df
df.shape
# Out:
# (38932, 5)

# %%
df.describe()
# Out:
#         User_ID                                        Description  \
# count     38932                                              38932
# unique    38932                                              38932
# top     id11596  We have stayed at Homewood Suites in suburbs t...
# freq          1                                                  1
#
#        Browser_Used Device_Used Is_Response
# count         38932       38932       38932
# unique           11           3           2
# top         Firefox     Desktop       happy
# freq           7367       15026       26521

# %%
df.dtypes
# Out:
# User_ID         object
# Description     object
# Browser_Used    object
# Device_Used     object
# Is_Response     object
# dtype: object

# %% [markdown]
# # Feature engineering
# lower the text
#
# tokenize the text (split the text into words) and remove the punctuation
#
# remove useless words that contain numbers
#
# remove useless stop words like 'the', 'a' ,'this' etc.
#
# Part-Of-Speech (POS) tagging: assign a tag to every word to define if it
# corresponds to a noun, a verb etc. using the WordNet lexical database

# %%
all_reviews = df['Description']
all_sent_values = []
all_sentiments = []

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()

# %%
from collections import Counter
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import warnings
import string
import nltk
warnings.filterwarnings('ignore')

# %%
df1['lower_case']=df1['Description'].apply(lambda x: ( x.lower()))
df1['lower_case']=(df1['lower_case'])

# %%
df1['cleanedtest'] = df1['lower_case'].str.replace(r'[^\w\d\s]', '')


# Replace whitespace between terms with a single space
df1['cleanedtest'] = df1['cleanedtest'].str.replace(r'\s+', ' ')

# Remove leading and trailing whitespace
df1['cleanedtest'] = df1['cleanedtest'].str.replace(r'^\s+|\s+?$!@#$%^&*_-+=:;"''"', '')

# %%
stop_words = set(stopwords.words('english') )

df1['cleanedtest'] = df1['cleanedtest'].apply(lambda x: ' '.join(term for term in x.split() if term not in stop_words))

# %%
k
# Out:
# 0        room kind clean strong smell dogs generally av...
# 1        stayed crown plaza april april staff friendly ...
# 2        booked hotel hotwire lowest price could find g...
# 3        stayed husband sons way alaska cruise loved ho...
# 4        girlfriends stayed celebrate th birthdays plan...
# 5        rooms one nice clearly updated recently clean ...
# 6        husband stayed hotel times though fanciest hot...
# 7        wife stayed glorious city back sf expensive fo...
# 8        boyfriend stayed fairmont recent trip san fran...
# 9        wonderful staff great location definately pric...
# 10       steps times square nice rooms stayed nights gr...
# 11       wife kids stayed valentines weekend really nic...
# 12       stay jolly madison xmas period main feature lo...
# 13       highly recommend hawthorne terrace affordable ...
# 14       found hotel clean nicely located good free shu...
# 15       stayed elan th th october liked much returned ...
# 16       priceline sent us hotel accepting bid usd nigh...
# 17       old cheap furnituresour chair simply destroyed...
# 18       stayed nights really happy located mins walk w...
# 19       service fine hotel fell way expectations respe...
# 20       stayed many hilton properties expect friendly ...
# 21       everything could want hotel convenient locatio...
# 22       much wanted stay boutique hotel near times squ...
# 23       really liked hotel staff wonderful quite helpf...
# 24       wife spent days month new york getaway vacatio...
# 25       stayed hotel two nights busy labor day weekend...
# 26       took girls trip la idea stay research settled ...
# 27       stayed girlfriend long weekend gave us nice co...
# 28       stayed numerous times never disappointed staff...
# 29       public areas nice look staff reception helpful...
#                                ...
# 38902    stayed waldorf many times think get going potl...
# 38903    hotel great choice staying manhattan booked pa...
# 38904    although new york large city whenever go must ...
# 38905    used live austin moved away could stay hotel a...
# 38906    ive stayed hilton hyatt magnolia club quarters...
# 38907    great locationshort walk amtrak station link g...
# 38908    booked renaissance hotel changed hands time ar...
# 38909    hotel old style red roof renovated new standar...
# 38910    admit tried rebooking since afraid bad reviews...
# 38911    room nice everything seemed pretty new room fe...
# 38912    great place stay hotel big impersonal lovely f...
# 38913    never ever stay hotel stayed weeks ago doubts ...
# 38914    bus hours finally arriving hotel lawerence baw...
# 38915    pretty cool hotel stayed days midjuly blast ba...
# 38916    stopped lax way canada loved staying sheraton ...
# 38917    love hotel stay several reasons despite one gr...
# 38918    excited stay blu aqua new hotel downtown chica...
# 38919    didnt get see much seattle hotel good location...
# 38920    husband stayed one night heartbreak hotel love...
# 38921    staed handlery hotel visit san diego going cru...
# 38922    hotel great location want right times square t...
# 38923    pretty impartial hotel would definitely never ...
# 38924    booked room two single beds upon arrival upgra...
# 38925    arrived via taxi la guardia driving th th saw ...
# 38926    tend post reviews ive exceptionally experience...
# 38927    arrived late night walked checkin area complet...
# 38928    positive impression location public parking op...
# 38929    traveling friends shopping show location great...
# 38930    experience ok paid extra view pool got view pa...
# 38931    westin wonderfully restored grande dame hotel ...
# Name: cleanedtest, Length: 38932, dtype: object

# %%
df1['neg']=df['Description'].apply(lambda x: analyser.polarity_scores(x)['neg'])

# %%
df1['neu']=df['Description'].apply(lambda x: analyser.polarity_scores(x)['neu'])
df1['pos']=df['Description'].apply(lambda x: analyser.polarity_scores(x)['pos'])
df1['compound']=df['Description'].apply(lambda x: analyser.polarity_scores(x)['compound'])

# %%
df1.head(4)
# Out:
#    User_ID                                        Description  \
# 0  id10326  The room was kind of clean but had a VERY stro...
# 1  id10327  I stayed at the Crown Plaza April -- - April -...
# 2  id10328  I booked this hotel through Hotwire at the low...
# 3  id10329  Stayed here with husband and sons on the way t...
#
#         Browser_Used Device_Used Is_Response  \
# 0               Edge      Mobile   not happy
# 1  Internet Explorer      Mobile   not happy
# 2            Mozilla      Tablet   not happy
# 3   InternetExplorer     Desktop       happy
#
#                                           lower_case  \
# 0  the room was kind of clean but had a very stro...
# 1  i stayed at the crown plaza april -- - april -...
# 2  i booked this hotel through hotwire at the low...
# 3  stayed here with husband and sons on the way t...
#
#                                          cleanedtest
# 0  room kind clean strong smell dogs generally av...
# 1  stayed crown plaza april april staff friendly ...
# 2  booked hotel hotwire lowest price could find g...
# 3  stayed husband sons way alaska cruise loved ho...

# %%
#sample data
sample = df['Description'][5]
print(sample)
print('Sentiment: ')
print(analyser.polarity_scores(sample)['compound'])
# Out:
# We had - rooms. One was very nice and clearly had been updated more recently than the other. The other was clean and the bed was comfy but it needed some updating (carpet was old and wrinkled for example). Great location for visiting Inner Harbor, getting to Fells Point, Orioles games etc. SuperShuttle from BWI worked great both ways. TV remotes in both rooms were terrible but we didn't watch much TV so not a big deal. Wireless was sketchy on --th and --th floors but again, didn't need it much - we were on vacation so it didn't really matter. Breakfast was good each morning. Would stay again if in town.
# Sentiment:
# 0.9472

# %%
df1.head(4)
# Out:
#    User_ID                                        Description  \
# 0  id10326  The room was kind of clean but had a VERY stro...
# 1  id10327  I stayed at the Crown Plaza April -- - April -...
# 2  id10328  I booked this hotel through Hotwire at the low...
# 3  id10329  Stayed here with husband and sons on the way t...
#
#         Browser_Used Device_Used Is_Response    neg    neu    pos  compound
# 0               Edge      Mobile   not happy  0.000  0.675  0.325    0.9628
# 1  Internet Explorer      Mobile   not happy  0.053  0.897  0.050   -0.1243
# 2            Mozilla      Tablet   not happy  0.048  0.866  0.085    0.9279
# 3   InternetExplorer     Desktop       happy  0.000  0.653  0.347    0.9920

# %%
compund=df1['compound']
SENTIMENT_VALUE = []
SENTIMENT = []
for i in compund:
    if (i<=1 and i>=0):
        SENTIMENT.append('happy')
        SENTIMENT_VALUE.append(2)
    else:
        SENTIMENT.append('not happy')
        SENTIMENT_VALUE.append(1)
#df['Is_Response']

# %%
SENTIMENT[0:5]
# Out:
# ['happy', 'not happy', 'happy', 'happy', 'happy']

# %%
df1=df
df1['SENTIMENT_VALUE']=SENTIMENT_VALUE
df1['SENTIMENT']=SENTIMENT

# %%
df1.head(4 )
# Out:
#    User_ID                                        Description  \
# 0  id10326  The room was kind of clean but had a VERY stro...
# 1  id10327  I stayed at the Crown Plaza April -- - April -...
# 2  id10328  I booked this hotel through Hotwire at the low...
# 3  id10329  Stayed here with husband and sons on the way t...
#
#         Browser_Used Device_Used Is_Response    neg    neu    pos  compound  \
# 0               Edge      Mobile   not happy  0.000  0.675  0.325    0.9628
# 1  Internet Explorer      Mobile   not happy  0.053  0.897  0.050   -0.1243
# 2            Mozilla      Tablet   not happy  0.048  0.866  0.085    0.9279
# 3   InternetExplorer     Desktop       happy  0.000  0.653  0.347    0.9920
#
#    SENTIMENT_VALUE  SENTIMENT
# 0                2      happy
# 1                1  not happy
# 2                2      happy
# 3                2      happy

# %% [markdown]
# # Exploratory data analysis
# In order to have a better understanding of our data, let's explore it a little:

# %%
plt.figure(figsize=(15,8))
sns.countplot('Browser_Used', data=df, color="darkturquoise")
plt.show()

# %%
sns.countplot('Device_Used', data=df, color="darkturquoise")
plt.show()

# %%
plt.figure(figsize=(20,14))
sns.heatmap(df.corr(),linewidths=.1,fmt="19f",cmap="YlGnBu", annot=True)
plt.yticks(rotation=0);

# %%
sns.pairplot(df)

# %%
sns.countplot(x='SENTIMENT',data=df1,linewidth=2,edgecolor=sns.color_palette("dark", 1))
print ('happy and not happy counts','\n',df.SENTIMENT.value_counts())
# Out:
# happy and not happy counts
#  happy        34743
# not happy     4189
# Name: SENTIMENT, dtype: int64

# %%
print ('happy and not happy counts','\n',df.Is_Response.value_counts())
sns.countplot(x='Is_Response',data=df1,linewidth=2,edgecolor=sns.color_palette("dark", 1))
# Out:
# happy and not happy counts
#  happy        26521
# not happy    12411
# Name: Is_Response, dtype: int64

# %%
ylabel2 = df1["compound"]
plt.ylabel("compound")
xlabel2 = df1["Device_Used"]
plt.xlabel("Device_Used")
plt.scatter(xlabel2, ylabel2, alpha=0.1)
plt.show()

# %%
for x in ['happy',  'not happy']:
    subset = df1[df1['Is_Response'] == x]
    
    # Draw the density plot
    if x == 'happy':
        label = "Good reviews"
    else:
        label = "Bad reviews"
    sns.distplot(subset['compound'], hist = False, label = label)

# %%
xaxis = []
for i in range(0,38932):
    xaxis.append(i)
    all_sent_values.append(df1['compound'][i])
ylabel_new_1 = all_sent_values[:38932]

xlabel = xaxis
plt.figure(figsize=(9,9))
plt.xlabel('ReviewIndex')
plt.ylabel('SentimentValue(-1 to 1)')
plt.plot(xlabel, ylabel_new_1, 'ro',  alpha=0.04)

plt.title('Scatter Intensity Plot of Sentiments')
plt.show()

# %%
from wordcloud import WordCloud
from nltk.corpus import  stopwords
zz = df['cleanedtest'][df['Is_Response']=='not happy']
zza = WordCloud(width=600,height=400,background_color='black',max_words=100).generate(' '.join(zz))
plt.figure(figsize=(10,10),facecolor='k')
plt.imshow(zza)
plt.axis('on')
plt.tight_layout(pad=0)
plt.show()

# %%
from wordcloud import WordCloud
from nltk.corpus import  stopwords
zz = df['Description'][df['Is_Response']=='happy']
zza = WordCloud(width=600,height=400,background_color='Black',max_words=100).generate(' '.join(zz))
plt.figure(figsize=(10,10),facecolor='k')
plt.imshow(zza)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# # Modelling reviewer_score

# %%
df1=df1.drop(['User_ID','Browser_Used','Is_Response','Device_Used','SENTIMENT_VALUE', 'SENTIMENT'],axis=1)

# %%
df1.head(4)
# Out:
#                                          Description    neg    neu    pos  \
# 0  The room was kind of clean but had a VERY stro...  0.000  0.675  0.325
# 1  I stayed at the Crown Plaza April -- - April -...  0.053  0.897  0.050
# 2  I booked this hotel through Hotwire at the low...  0.048  0.866  0.085
# 3  Stayed here with husband and sons on the way t...  0.000  0.653  0.347
#
#    compound
# 0    0.9628
# 1   -0.1243
# 2    0.9279
# 3    0.9920

# %% [markdown]
# #### using countvectorizer

# %%
vect1 = CountVectorizer(ngram_range=(1,1))


X = df1.loc[:,('cleanedtest')]

features = vect1.fit_transform(X)

X = features
y = df['Is_Response']
X_train,x_test,Y_train,y_test = train_test_split(X,y,random_state=42)

# %%
#model formation
naive = MultinomialNB()
rf = RandomForestClassifier(n_estimators = 100, random_state = 42)
svm = SVC(random_state = 1)
dtc = DecisionTreeClassifier()
knn = KNeighborsClassifier(n_neighbors = 2)
model = LogisticRegression()
z=[svm,dtc,knn,model,rf,naive]
for i in z:
    i.fit(X_train,Y_train)
    y_pred = i.predict(x_test)
    print ('Final score {} = >' .format( i ) , accuracy_score(y_test,y_pred))
    print(classification_report(y_test, y_pred))

    conf_mat = confusion_matrix(y_test,y_pred)

    ax=plt.subplot()

    sns.heatmap(conf_mat,annot=True,ax=ax,linewidths=5,linecolor='r',center=0)

    ax.set_xlabel('Predicted Labels');ax.set_ylabel('True Labels')

    ax.set_title('Confusion matrix')
    ax.xaxis.set_ticklabels(['happy','nothappy'])
    ax.yaxis.set_ticklabels(['happy','nothappy'])
    plt.show()
# Out:
# Final score SVC(random_state=1) = > 0.8776327956436865
#               precision    recall  f1-score   support
#
#        happy       0.89      0.94      0.91      6637
#    not happy       0.85      0.75      0.80      3096
#
#     accuracy                           0.88      9733
#    macro avg       0.87      0.84      0.85      9733
# weighted avg       0.88      0.88      0.88      9733
# Final score DecisionTreeClassifier() = > 0.7521832939484229
#               precision    recall  f1-score   support
#
#        happy       0.81      0.83      0.82      6637
#    not happy       0.62      0.59      0.60      3096
#
#     accuracy                           0.75      9733
#    macro avg       0.71      0.71      0.71      9733
# weighted avg       0.75      0.75      0.75      9733
# Final score KNeighborsClassifier(n_neighbors=2) = > 0.7028665365252235
#               precision    recall  f1-score   support
#
#        happy       0.70      0.99      0.82      6637
#    not happy       0.76      0.10      0.17      3096
#
#     accuracy                           0.70      9733
#    macro avg       0.73      0.54      0.49      9733
# weighted avg       0.72      0.70      0.61      9733
# Final score LogisticRegression() = > 0.8665365252234666
#               precision    recall  f1-score   support
#
#        happy       0.89      0.92      0.90      6637
#    not happy       0.81      0.75      0.78      3096
#
#     accuracy                           0.87      9733
#    macro avg       0.85      0.84      0.84      9733
# weighted avg       0.86      0.87      0.87      9733
# Final score RandomForestClassifier(random_state=42) = > 0.8274940922634337
#               precision    recall  f1-score   support
#
#        happy       0.81      0.98      0.89      6637
#    not happy       0.92      0.50      0.65      3096
#
#     accuracy                           0.83      9733
#    macro avg       0.86      0.74      0.77      9733
# weighted avg       0.84      0.83      0.81      9733
# Final score MultinomialNB() = > 0.8641734305969383
#               precision    recall  f1-score   support
#
#        happy       0.88      0.93      0.90      6637
#    not happy       0.82      0.73      0.77      3096
#
#     accuracy                           0.86      9733
#    macro avg       0.85      0.83      0.84      9733
# weighted avg       0.86      0.86      0.86      9733

# %%
pprint(rf.get_params())
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 42,
#  'verbose': 0,
#  'warm_start': False}

# %%
bootstrap_v = [True, False]
n_estimators_v = list(range(100,38932,200))
criterion = ['gini', 'entropy']
min_sample_leaf_v = list(range(1,5,2))
max_features_v = ['sqrt', 'log2']

# %%
grid_params  = {
    'bootstrap' : bootstrap_v,
    'n_estimators' : n_estimators_v,
    'criterion' : criterion,
    'min_samples_leaf' : min_sample_leaf_v,
    'max_features' : max_features_v
}

print("Tuning Parameters")
print('='*50)
pprint(grid_params)
print('='*50)
# Out:
# Tuning Parameters
# ==================================================
# {'bootstrap': [True, False],
#  'criterion': ['gini', 'entropy'],
#  'max_features': ['sqrt', 'log2'],
#  'min_samples_leaf': [1, 3],
#  'n_estimators': [100,
#                   300,
#                   500,
#                   700,
#                   900,
#                   1100,
#                   1300,
#                   1500,
#                   1700,
#                   1900,
#                   2100,
#                   2300,
#                   2500,
#                   2700,
#                   2900,
#                   3100,
#                   3300,
#                   3500,
#                   3700,
#                   3900,
#                   4100,
#                   4300,
#                   4500,
#                   4700,
#                   4900,
#                   5100,
#                   5300,
#                   5500,
#                   5700,
#                   5900,
#                   6100,
#                   6300,
#                   6500,
#                   6700,
#                   6900,
#                   7100,
#                   7300,
#                   7500,
#                   7700,
#                   7900,
#                   8100,
#                   8300,
#                   8500,
#                   8700,
#                   8900,
#                   9100,
#                   9300,
#                   9500,
#                   9700,
#                   9900,
#                   10100,
#                   10300,
#                   10500,
#                   10700,
#                   10900,
#                   11100,
#                   11300,
#                   11500,
#                   11700,
#                   11900,
#                   12100,
#                   12300,
#                   12500,
#                   12700,
#                   12900,
#                   13100,
#                   13300,
#                   13500,
#                   13700,
#                   13900,
#                   14100,
#                   14300,
#                   14500,
#                   14700,
#                   14900,
#                   15100,
#                   15300,
#                   15500,
#                   15700,
#                   15900,
#                   16100,
#                   16300,
#                   16500,
#                   16700,
#                   16900,
#                   17100,
#                   17300,
#                   17500,
#                   17700,
#                   17900,
#                   18100,
#                   18300,
#                   18500,
#                   18700,
#                   18900,
#                   19100,
#                   19300,
#                   19500,
#                   19700,
#                   19900,
#                   20100,
#                   20300,
#                   20500,
#                   20700,
#                   20900,
#                   21100,
#                   21300,
#                   21500,
#                   21700,
#                   21900,
#                   22100,
#                   22300,
#                   22500,
#                   22700,
#                   22900,
#                   23100,
#                   23300,
#                   23500,
#                   23700,
#                   23900,
#                   24100,
#                   24300,
#                   24500,
#                   24700,
#                   24900,
#                   25100,
#                   25300,
#                   25500,
#                   25700,
#                   25900,
#                   26100,
#                   26300,
#                   26500,
#                   26700,
#                   26900,
#                   27100,
#                   27300,
#                   27500,
#                   27700,
#                   27900,
#                   28100,
#                   28300,
#                   28500,
#                   28700,
#                   28900,
#                   29100,
#                   29300,
#                   29500,
#                   29700,
#                   29900,
#                   30100,
#                   30300,
#                   30500,
#                   30700,
#                   30900,
#                   31100,
#                   31300,
#                   31500,
#                   31700,
#                   31900,
#                   32100,
#                   32300,
#                   32500,
#                   32700,
#                   32900,
#                   33100,
#                   33300,
#                   33500,
#                   33700,
#                   33900,
#                   34100,
#                   34300,
#                   34500,
#                   34700,
#                   34900,
#                   35100,
#                   35300,
#                   35500,
#                   35700,
#                   35900,
#                   36100,
#                   36300,
#                   36500,
#                   36700,
#                   36900,
#                   37100,
#                   37300,
#                   37500,
#                   37700,
#                   37900,
#                   38100,
#                   38300,
#                   38500,
#                   38700,
#                   38900]}
# ==================================================

# %%
grid_search = GridSearchCV(estimator=rf, param_grid=grid_params, cv=3, verbose=1)

# %%
grid_search.fit(X_train, Y_train)

print('Best Parameters for our classsifier')
print('='*50)
print(grid_search.best_params_)
print('='*50)
# Out:
# Fitting 3 folds for each of 3120 candidates, totalling 9360 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.

# %% [markdown]
# #### using Tfidvector

# %%
tf_vec = TfidfVectorizer()
#vect1 = CountVectorizer(ngram_range=(1,1))


X = df1.loc[:,('cleanedtest')]

features = tf_vec.fit_transform(X)

X = features
y = df['Is_Response']
X_train,x_test,Y_train,y_test = train_test_split(X,y,random_state=42)

# %%
accuracy_score1=[]
naive = MultinomialNB()
rf = RandomForestClassifier(n_estimators = 100, random_state = 42)
svm = SVC(random_state = 1)
dtc = DecisionTreeClassifier()
knn = KNeighborsClassifier(n_neighbors = 2)
model = LogisticRegression()
z=[svm,dtc,knn,model,rf,naive]
for i in z:
    i.fit(X_train,Y_train)
    y_pred = i.predict(x_test)
    print('final score {} = >' .format(i),accuracy_score(y_test,y_pred))
    print(classification_report(y_test, y_pred))
    accuracy_score1.append(accuracy_score(y_test,y_pred))
    conf_mat = confusion_matrix(y_test,y_pred)

    ax=plt.subplot()

    sns.heatmap(conf_mat,ax=ax,annot=True,cmap="Blues",fmt="d",cbar=False, annot_kws={"size": 24})
    #sns.heatmap(conf_mat,annot=True,ax=ax,linewidths=5,linecolor='r',center=0)
    ax.set_xlabel('Predicted Labels');ax.set_ylabel('True Labels')

    ax.set_title('Confusion matrix')
    ax.xaxis.set_ticklabels(['happy','nothappy'])
    ax.yaxis.set_ticklabels(['happy','nothappy'])
    plt.show()

# %% [markdown]
# # Model Selection

# %% [markdown]
# ###### SVM

# %%
df2=df2.drop(['Browser_Used','Device_Used','User_ID'],axis=1)
df2.shape
# Out:
# (29404, 1)

# %%
tf_vec = TfidfVectorizer()

# %%
features = tf_vec.fit_transform(df['Description'])
features1 = tf_vec.transform(df2['Description'])

target = df['Is_Response']

# %%
svm = SVC(random_state = 1)
svm.fit(features,target)

# %%
y_pred= svm.predict(features1)

# %% [markdown]
# # Result save

# %%
s=pd.DataFrame(y_pred,columns=['Is_Response'])
s.to_csv(r'dataframe.csv', index = False, header=True)
